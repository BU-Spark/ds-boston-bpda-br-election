# %% [markdown]
# ## Team 2 - Deliverable 1
#
# This folder contains graphs from our cleaned data using `example.py`

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sum_party_votes = pd.read_csv('election data/sum_party_votes.csv')
sum_party_votes = sum_party_votes.rename({'Unnamed: 0': 'Year'}, axis='columns')
print(sum_party_votes)
# Out:
#    Year  PARTIDO SOCIAL DEMOCRATA CRISTÃO  PARTIDO TRABALHISTA DO BRASIL  \
# 0  1998                              17.0                           86.0
# 1  2002                               NaN                            NaN
# 2  2006                             131.0                            NaN
# 3  2010                             357.0                            NaN
# 4  2014                               NaN                            NaN
# 5  2018                               NaN                            NaN
#
#    PARTIDO DOS TRABALHADORES  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  \
# 0                     4885.0                                  13848.0
# 1                    39365.0                                  23960.0
# 2                   133996.0                                 153700.0
# 3                    64148.0                                  81846.0
# 4                        NaN                                      NaN
# 5                        NaN                                      NaN
#
#    PARTIDO TRABALHISTA NACIONAL  PARTIDO DA REEDIFICAÇÃO DA ORDEM NACIONAL  \
# 0                          85.0                                      307.0
# 1                           NaN                                        NaN
# 2                           NaN                                        NaN
# 3                           NaN                                        NaN
# 4                           NaN                                        NaN
# 5                           NaN                                        NaN
#
#    PARTIDO POPULAR SOCIALISTA  PARTIDO SOCIALISTA DOS TRABALHADORES UNIFICADO  \
# 0                      1407.0                                            45.0
# 1                      4342.0                                           204.0
# 2                         NaN                                             NaN
# 3                         NaN                                           541.0
# 4                         NaN                                             NaN
# 5                         NaN                                             NaN
#
#    PARTIDO DA MOBILIZAÇÃO NACIONAL  ...  Partido da Causa Operária  \
# 0                             61.0  ...                        NaN
# 1                              NaN  ...                        NaN
# 2                              NaN  ...                        NaN
# 3                              NaN  ...                        NaN
# 4                              NaN  ...                       73.0
# 5                              NaN  ...                        NaN
#
#    Partido Social Liberal  Podemos  Movimento Democrático Brasileiro  \
# 0                     NaN      NaN                               NaN
# 1                     NaN      NaN                               NaN
# 2                     NaN      NaN                               NaN
# 3                     NaN      NaN                               NaN
# 4                     NaN      NaN                               NaN
# 5                245361.0   2733.0                             952.0
#
#    Democracia Cristã  Partido Novo  Patriota  Rede Sustentabilidade  \
# 0                NaN           NaN       NaN                    NaN
# 1                NaN           NaN       NaN                    NaN
# 2                NaN           NaN       NaN                    NaN
# 3                NaN           NaN       NaN                    NaN
# 4                NaN           NaN       NaN                    NaN
# 5              179.0       13637.0    1172.0                 4961.0
#
#    Partido Pátria Livre  Partido Democrático Trabalhista
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
# 5                 153.0                          28073.0
#
# [6 rows x 41 columns]

# %%
# Function to graph votes for any party
def graphPartyVotes(df, party):
    x = sum_party_votes.Year.values
    oldList = sum_party_votes[party].values
    y =[]
    for i in range(len(oldList) - 1, -1, -1):
        votes = oldList[i]
        if np.isnan(votes) == False:
            y.insert(0,votes)
        else:
            x = np.delete(x, i)

    m, b = np.polyfit(x, y, 1)
    plt.plot(x, y, 'o')
    plt.plot(x, m*x + b)
    plt.xlabel("Year")
    plt.ylabel("Votes")
    plt.title("Votes for " + party)
    plt.show()

# %%
# Graph votes for each party
parties = sum_party_votes.columns[1:]
for party in parties:
    graphPartyVotes(sum_party_votes, party)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
